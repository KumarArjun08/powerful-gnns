# %%
import networkx as nx
import numpy as np
import random
import torch
from sklearn.model_selection import StratifiedKFold

class S2VGraph(object):
    def __init__(self, g, label, node_tags=None, node_features=None):
        '''
            g: a networkx graph
            label: an integer graph label
            node_tags: a list of integer node tags
            node_features: a torch float tensor, one-hot representation of the tag that is used as input to neural nets
            edge_mat: a torch long tensor, contain edge list, will be used to create torch sparse tensor
            neighbors: list of neighbors (without self-loop)
        '''
        self.label = label
        self.g = g
        self.node_tags = node_tags
        self.neighbors = []
        self.node_features = 0
        self.edge_mat = 0

        self.max_neighbor = 0

# %%
import coarsening
# data=load_data('MUTAG',True)
def coarsen_dataset(g_list):
    g=0
    g_mat=[]
    Node_tag_list=[]
    g_list2=[]
    while g < len(g_list):
        adj_matrix=nx.adjacency_matrix(g_list[g].g).toarray()
        adj_matrix=torch.Tensor(adj_matrix)
        # print(adj_matrix)
        X=np.array(g_list[g].node_tags).reshape(len(g_list[g].node_tags),1)
        X=torch.tensor(X)
        adj_matrix,X2=coarsening.coarsening(adj_matrix,X)
        adj_matrix=adj_matrix.numpy()
        grap=nx.from_numpy_array(adj_matrix)
        g_mat.append(grap)
        X2=X2.reshape(1,len(X2))
        X2=X2.tolist()
        Node_tag_list.append(X2[0])
        
        g_list2.append(S2VGraph(grap,g_list[g].label,X2[0]))
        g+=1
    return g_list2
    
# print(coarsen_dataset(data))

# %%
def load_data(dataset, degree_as_tag):
    '''
        dataset: name of dataset
        test_proportion: ratio of test train split
        seed: random seed for random splitting of dataset
    '''

    print('loading data')
    g_list = []
    label_dict = {}
    feat_dict = {}

    with open('dataset/%s/%s.txt' % (dataset, dataset), 'r') as f:
        n_g = int(f.readline().strip())
        for i in range(n_g):
            row = f.readline().strip().split()
            n, l = [int(w) for w in row]
            if not l in label_dict:
                mapped = len(label_dict)
                label_dict[l] = mapped
            g = nx.Graph()
            node_tags = []
            node_features = []
            n_edges = 0
            for j in range(n):
                g.add_node(j)
                row = f.readline().strip().split()
                tmp = int(row[1]) + 2
                if tmp == len(row):
                    # no node attributes
                    row = [int(w) for w in row]
                    attr = None
                else:
                    row, attr = [int(w) for w in row[:tmp]], np.array([float(w) for w in row[tmp:]])
                if not row[0] in feat_dict:
                    mapped = len(feat_dict)
                    feat_dict[row[0]] = mapped
                node_tags.append(feat_dict[row[0]])

                if tmp > len(row):
                    node_features.append(attr)

                n_edges += row[1]
                for k in range(2, len(row)):
                    g.add_edge(j, row[k])

            if node_features != []:
                node_features = np.stack(node_features)
                node_feature_flag = True
            else:
                node_features = None
                node_feature_flag = False

            assert len(g) == n

            g_list.append(S2VGraph(g, l, node_tags))
    g_list=coarsen_dataset(g_list)
    #add labels and edge_mat       
    for g in g_list:
        g.neighbors = [[] for i in range(len(g.g))]
        for i, j in g.g.edges():
            g.neighbors[i].append(j)
            g.neighbors[j].append(i)
        degree_list = []
        for i in range(len(g.g)):
            g.neighbors[i] = g.neighbors[i]
            degree_list.append(len(g.neighbors[i]))
        g.max_neighbor = max(degree_list)

        g.label = label_dict[g.label]

        edges = [list(pair) for pair in g.g.edges()]
        edges.extend([[i, j] for j, i in edges])

        deg_list = list(dict(g.g.degree(range(len(g.g)))).values())
        g.edge_mat = torch.LongTensor(edges).transpose(0,1)

    if degree_as_tag:
        for g in g_list:
            g.node_tags = list(dict(g.g.degree).values())

    #Extracting unique tag labels   
    tagset = set([])
    for g in g_list:
        tagset = tagset.union(set(g.node_tags))

    tagset = list(tagset)
    tag2index = {tagset[i]:i for i in range(len(tagset))}

    for g in g_list:
        g.node_features = torch.zeros(len(g.node_tags), len(tagset))
        g.node_features[range(len(g.node_tags)), [tag2index[tag] for tag in g.node_tags]] = 1


    print('# classes: %d' % len(label_dict))
    print('# maximum node tag: %d' % len(tagset))

    print("# data: %d" % len(g_list))

    return g_list, len(label_dict)

# %%
def separate_data(graph_list, seed, fold_idx):
    assert 0 <= fold_idx and fold_idx < 10, "fold_idx must be from 0 to 9."
    skf = StratifiedKFold(n_splits=10, shuffle = True, random_state = seed)

    labels = [graph.label for graph in graph_list]
    idx_list = []
    for idx in skf.split(np.zeros(len(labels)), labels):
        idx_list.append(idx)
    train_idx, test_idx = idx_list[fold_idx]

    train_graph_list = [graph_list[i] for i in train_idx]
    test_graph_list = [graph_list[i] for i in test_idx]

    return train_graph_list, test_graph_list

# %%
data=load_data('MUTAG',True)
print(data)
# Out:
# loading data
# 100%|██████████| 20/20 [00:00<00:00, 489.13it/s]
# 100%|██████████| 20/20 [00:00<00:00, 557.04it/s]
# 100%|██████████| 20/20 [00:00<00:00, 646.87it/s]
# 100%|██████████| 20/20 [00:00<00:00, 534.61it/s]
# 100%|██████████| 20/20 [00:00<00:00, 541.93it/s]
# 100%|██████████| 20/20 [00:00<00:00, 507.43it/s]
# 100%|██████████| 20/20 [00:00<00:00, 378.37it/s]
# 100%|██████████| 20/20 [00:00<00:00, 514.20it/s]
# 100%|██████████| 20/20 [00:00<00:00, 358.07it/s]
# 100%|██████████| 20/20 [00:00<00:00, 557.05it/s]
#  10%|█         | 2/20 [00:00<00:00, 222.82it/s]
# 100%|██████████| 20/20 [00:00<00:00, 541.97it/s]
# 100%|██████████| 20/20 [00:00<00:00, 323.46it/s]
# 100%|██████████| 20/20 [00:00<00:00, 172.88it/s]
# 100%|██████████| 20/20 [00:00<00:00, 392.75it/s]
# 100%|██████████| 20/20 [00:00<00:00, 311.78it/s]
# 100%|██████████| 20/20 [00:00<00:00, 392.49it/s]
# 100%|██████████| 20/20 [00:00<00:00, 356.83it/s]
# 100%|██████████| 20/20 [00:00<00:00, 392.45it/s]
# 100%|██████████| 20/20 [00:00<00:00, 337.01it/s]
#  10%|█         | 2/20 [00:00<00:00, 200.56it/s]
# 100%|██████████| 20/20 [00:00<00:00, 282.41it/s]
# 100%|██████████| 20/20 [00:00<00:00, 384.69it/s]
# 100%|██████████| 20/20 [00:00<00:00, 336.97it/s]
# 100%|██████████| 20/20 [00:00<00:00, 299.30it/s]
# 100%|██████████| 20/20 [00:00<00:00, 835.59it/s]
#  10%|█         | 2/20 [00:00<00:00, 334.25it/s]
#  10%|█         | 2/20 [00:00<00:00, 401.08it/s]
# 100%|██████████| 20/20 [00:00<00:00, 771.28it/s]
# 100%|██████████| 20/20 [00:00<00:00, 771.27it/s]
# 100%|██████████| 20/20 [00:00<00:00, 871.75it/s]
# 100%|██████████| 20/20 [00:00<00:00, 954.99it/s]
# 100%|██████████| 20/20 [00:00<00:00, 1002.73it/s]
# 100%|██████████| 20/20 [00:00<00:00, 1002.70it/s]
# 100%|██████████| 20/20 [00:00<00:00, 771.32it/s]
# 100%|██████████| 20/20 [00:00<00:00, 774.04it/s]
# 100%|██████████| 20/20 [00:00<00:00, 771.20it/s]
# 100%|██████████| 20/20 [00:00<00:00, 835.58it/s]
# 100%|██████████| 20/20 [00:00<00:00, 954.91it/s]
# 100%|██████████| 20/20 [00:00<00:00, 742.72it/s]
# 100%|██████████| 20/20 [00:00<00:00, 802.18it/s]
# 100%|██████████| 20/20 [00:00<00:00, 802.13it/s]
# 100%|██████████| 20/20 [00:00<00:00, 1002.70it/s]
# 100%|██████████| 20/20 [00:00<00:00, 934.67it/s]
# 100%|██████████| 20/20 [00:00<00:00, 742.93it/s]
# 100%|██████████| 20/20 [00:00<00:00, 802.27it/s]
# 100%|██████████| 20/20 [00:00<00:00, 835.54it/s]
# # classes: 2
# # maximum node tag: 13
# # data: 188
# ([<__main__.S2VGraph object at 0x000001C4C8DFDAB0>, <__main__.S2VGraph object at 0x000001C4C8DFC6D0>, <__main__.S2VGraph object at 0x000001C4C5B61000>, <__main__.S2VGraph object at 0x000001C4FFAFFE50>, <__main__.S2VGraph object at 0x000001C4C8A428C0>, <__main__.S2VGraph object at 0x000001C4C8A404F0>, <__main__.S2VGraph object at 0x000001C4C5AC54B0>, <__main__.S2VGraph object at 0x000001C4C8E67F70>, <__main__.S2VGraph object at 0x000001C4C5B60250>, <__main__.S2VGraph object at 0x000001C4C5C58F70>, <__main__.S2VGraph object at 0x000001C4C8A41540>, <__main__.S2VGraph object at 0x000001C4FC13AE60>, <__main__.S2VGraph object at 0x000001C4C8A43370>, <__main__.S2VGraph object at 0x000001C4C8E644C0>, <__main__.S2VGraph object at 0x000001C4C8E64B20>, <__main__.S2VGraph object at 0x000001C4C5A30BE0>, <__main__.S2VGraph object at 0x000001C4C6B3ABC0>, <__main__.S2VGraph object at 0x000001C4FC13A680>, <__main__.S2VGraph object at 0x000001C4C8A40D00>, <__main__.S2VGraph object at 0x000001C4C5A31420>, <__main__.S2VGraph object at 0x000001C4C6B3BBE0>, <__main__.S2VGraph object at 0x000001C4C6B3B1C0>, <__main__.S2VGraph object at 0x000001C4C5A32020>, <__main__.S2VGraph object at 0x000001C4C5A31DB0>, <__main__.S2VGraph object at 0x000001C4C5A31570>, <__main__.S2VGraph object at 0x000001C4C8E66D40>, <__main__.S2VGraph object at 0x000001C4C6B38A30>, <__main__.S2VGraph object at 0x000001C4C6B385B0>, <__main__.S2VGraph object at 0x000001C4C8A41360>, <__main__.S2VGraph object at 0x000001C4C8E64550>, <__main__.S2VGraph object at 0x000001C4C8E65BD0>, <__main__.S2VGraph object at 0x000001C4C5A31D50>, <__main__.S2VGraph object at 0x000001C4C6B3B040>, <__main__.S2VGraph object at 0x000001C4C5A33610>, <__main__.S2VGraph object at 0x000001C4C5B7CEB0>, <__main__.S2VGraph object at 0x000001C4C8E65360>, <__main__.S2VGraph object at 0x000001C4C6B3A440>, <__main__.S2VGraph object at 0x000001C4C6AB65F0>, <__main__.S2VGraph object at 0x000001C4C5B7FB50>, <__main__.S2VGraph object at 0x000001C4C5A32800>, <__main__.S2VGraph object at 0x000001C4C8A40AF0>, <__main__.S2VGraph object at 0x000001C4C6B39EA0>, <__main__.S2VGraph object at 0x000001C4C6AB6E30>, <__main__.S2VGraph object at 0x000001C4C6AB74F0>, <__main__.S2VGraph object at 0x000001C4C5B7D9C0>, <__main__.S2VGraph object at 0x000001C4C6B38C70>, <__main__.S2VGraph object at 0x000001C4C6AB79D0>, <__main__.S2VGraph object at 0x000001C4C6AB5D20>, <__main__.S2VGraph object at 0x000001C4C6AB40D0>, <__main__.S2VGraph object at 0x000001C4C5A30DF0>, <__main__.S2VGraph object at 0x000001C4C6B39870>, <__main__.S2VGraph object at 0x000001C4C6B3B4C0>, <__main__.S2VGraph object at 0x000001C4C6AB5E10>, <__main__.S2VGraph object at 0x000001C4C6AB5630>, <__main__.S2VGraph object at 0x000001C4C5B44220>, <__main__.S2VGraph object at 0x000001C4C6B3AD40>, <__main__.S2VGraph object at 0x000001C4C5A31AE0>, <__main__.S2VGraph object at 0x000001C4C5B44520>, <__main__.S2VGraph object at 0x000001C4C6AB7BE0>, <__main__.S2VGraph object at 0x000001C4C6AB6050>, <__main__.S2VGraph object at 0x000001C4C5A31900>, <__main__.S2VGraph object at 0x000001C4C5B46A40>, <__main__.S2VGraph object at 0x000001C4C6B3A560>, <__main__.S2VGraph object at 0x000001C4C6AB63B0>, <__main__.S2VGraph object at 0x000001C4C6AB54B0>, <__main__.S2VGraph object at 0x000001C4C6AB61A0>, <__main__.S2VGraph object at 0x000001C4C5B440A0>, <__main__.S2VGraph object at 0x000001C4C5A32440>, <__main__.S2VGraph object at 0x000001C4C5B7C3A0>, <__main__.S2VGraph object at 0x000001C4C8A40610>, <__main__.S2VGraph object at 0x000001C4C5A31750>, <__main__.S2VGraph object at 0x000001C4C5A31FF0>, <__main__.S2VGraph object at 0x000001C4C6B3AC80>, <__main__.S2VGraph object at 0x000001C4C6B3AA40>, <__main__.S2VGraph object at 0x000001C4C6B38BB0>, <__main__.S2VGraph object at 0x000001C4C6B39450>, <__main__.S2VGraph object at 0x000001C4C6B3AF50>, <__main__.S2VGraph object at 0x000001C4C5AC6A10>, <__main__.S2VGraph object at 0x000001C4C5A31BA0>, <__main__.S2VGraph object at 0x000001C4C5B7EC20> ...
